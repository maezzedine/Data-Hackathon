# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in e:\applications\programs\anaconda3\envs\newenvt\lib\site-packages (3.0.5)
# Requirement already satisfied: et-xmlfile in e:\applications\programs\anaconda3\envs\newenvt\lib\site-packages (from openpyxl) (1.0.1)
# Requirement already satisfied: jdcal in e:\applications\programs\anaconda3\envs\newenvt\lib\site-packages (from openpyxl) (1.4.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import glob
import pandas as pd
import openpyxl
import numpy as np
#import psycopg2 as ps
import matplotlib.pyplot as plt

# %%
#combined sheets
df = pd.read_excel('data.xlsx', sheet_name='Sheet 1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-b46e58962169> in <module>
#       1 #combined sheets
# ----> 2 df = pd.read_excel('data.xls', sheet_name='Sheet 1')
#
# E:\Applications\Programs\Anaconda3\envs\newenvt\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# E:\Applications\Programs\Anaconda3\envs\newenvt\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
#     303     if not isinstance(io, ExcelFile):
# --> 304         io = ExcelFile(io, engine=engine)
#     305     elif engine and engine != io.engine:
#     306         raise ValueError(
#
# E:\Applications\Programs\Anaconda3\envs\newenvt\lib\site-packages\pandas\io\excel\_base.py in __init__(self, path_or_buffer, engine)
#     865         self._io = stringify_path(path_or_buffer)
#     866
# --> 867         self._reader = self._engines[engine](self._io)
#     868
#     869     def __fspath__(self):
#
# E:\Applications\Programs\Anaconda3\envs\newenvt\lib\site-packages\pandas\io\excel\_xlrd.py in __init__(self, filepath_or_buffer)
#      20         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      21         import_optional_dependency("xlrd", extra=err_msg)
# ---> 22         super().__init__(filepath_or_buffer)
#      23
#      24     @property
#
# E:\Applications\Programs\Anaconda3\envs\newenvt\lib\site-packages\pandas\io\excel\_base.py in __init__(self, filepath_or_buffer)
#     351             self.book = self.load_workbook(filepath_or_buffer)
#     352         elif isinstance(filepath_or_buffer, str):
# --> 353             self.book = self.load_workbook(filepath_or_buffer)
#     354         elif isinstance(filepath_or_buffer, bytes):
#     355             self.book = self.load_workbook(BytesIO(filepath_or_buffer))
#
# E:\Applications\Programs\Anaconda3\envs\newenvt\lib\site-packages\pandas\io\excel\_xlrd.py in load_workbook(self, filepath_or_buffer)
#      35             return open_workbook(file_contents=data)
#      36         else:
# ---> 37             return open_workbook(filepath_or_buffer)
#      38
#      39     @property
#
# E:\Applications\Programs\Anaconda3\envs\newenvt\lib\site-packages\xlrd\__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     109     else:
#     110         filename = os.path.expanduser(filename)
# --> 111         with open(filename, "rb") as f:
#     112             peek = f.read(peeksz)
#     113     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.xls'

# %%
# we dropped empty rows so we went from 507 to 388 ops 
df.dropna(subset = ["Name"], inplace=True)

# %%
df
# Out:
#                        Name  \
# 0    Dr. Hilal El Misilmani
# 1            Basma Frangieh
# 2          Hassan Nasrallah
# 3               Tony Kassab
# 4              Elie Yammine
# ..                      ...
# 500           Perla Ibrahim
# 501        SarkiS Fadlallah
# 502      Youssef Noureddine
# 503             Fadi Haddad
# 504          Elias Chalouhy
#
#                                                    Job  \
# 0    Assistant Professor | Graduate Studies Coordin...
# 1    Présidente de T.I.E.S (Together for Inclusive ...
# 2    Graduate Research Assistant - Computer Vision ...
# 3                     Molecular and cellular biologist
# 4               Statistician at Statistics Lebanon Ltd
# ..                                                 ...
# 500  Accountant at Logistica SAL - Obegi Consumer P...
# 501  Telecommunications Specialist at Advanced Inte...
# 502                  Computer & Communication Engineer
# 503                         Computer Engineer Graduate
# 504  Master's student in Computer Communication Eng...
#
#                                     Location  \
# 0                       Lebanon Contact info
# 1                       Lebanon Contact info
# 2                       Lebanon Contact info
# 3               Beirut, Lebanon Contact info
# 4    Qabb Elias, Beqaa, Lebanon Contact info
# ..                                       ...
# 500                     Lebanon Contact info
# 501                     Lebanon Contact info
# 502                     Lebanon Contact info
# 503     Tripoli, North, Lebanon Contact info
# 504                     Lebanon Contact info
#
#                                              Company  \
# 0                             Beirut Arab University
# 1        Université Libanaise - Faculté de Pédagogie
# 2    National Council for Scientific Research (CNRS)
# 3                                Lebanese university
# 4                             Statistics Lebanon Ltd
# ..                                               ...
# 500                  Obegi Consumer Products Holding
# 501                Advanced Integration Technologies
# 502                Lebanese International University
# 503                                  AI Venture Labs
# 504                      Université de Franche-Comté
#
#                                               College  \
# 0                       American University of Beirut
# 1                                                 NaN
# 2    Lebanese University - Faculty of Engineering III
# 3                                                 NaN
# 4           Lebanese University - Faculty of Sciences
# ..                                                ...
# 500                                               NaN
# 501                                               NaN
# 502                                               NaN
# 503                 Lebanese International University
# 504                                               NaN
#
#                                           LinkedinLink  Projects  Languages  \
# 0          https://lb.linkedin.com/in/hilalelmisilmani       NaN        3.0
# 1    https://lb.linkedin.com/in/basma-frangieh-0493...       2.0        3.0
# 2    https://lb.linkedin.com/in/hassan-nasrallah-38...       6.0        NaN
# 3     https://lb.linkedin.com/in/tony-kassab-75936a139       NaN        NaN
# 4    https://lb.linkedin.com/in/elie-yammine-a5b61918a       NaN        NaN
# ..                                                 ...       ...        ...
# 500  https://lb.linkedin.com/in/perla-ibrahim-6632a...       NaN        3.0
# 501  https://lb.linkedin.com/in/sarkis-fadlallah-18...       NaN        NaN
# 502  https://lb.linkedin.com/in/youssef-noureddine-...       NaN        NaN
# 503   https://lb.linkedin.com/in/fadi-haddad-4303a5164       NaN        NaN
# 504          https://lb.linkedin.com/in/elias-chalouhy       NaN        NaN
#
#                                             Experience  \
# 0                                                  NaN
# 1     \nConsultante en sciences de l'éducation - - ...
# 2     \nGraduate Research Assistant - Computer Visi...
# 3                                                  NaN
# 4     \nStatistician - Statistics Lebanon Ltd Full-...
# ..                                                 ...
# 500   \nAccountant - Obegi Consumer Products Holdin...
# 501                                                NaN
# 502                                                NaN
# 503   \nMachine Learning & AI Intern - AI Venture L...
# 504                                                NaN
#
#                                     ExperienceDuration  \
# 0                                                  NaN
# 1    5 yrs 8 mos\n2 yrs 5 mos\n11 mos\n1 yr\nLocati...
# 2                                7 mos\n6 mos\n3 mos\n
# 3                                                  NaN
# 4                                       2 mos\n9 mos\n
# ..                                                 ...
# 500  6 mos\n1 mo\n1 mo\nless than a year\nless than...
# 501                                                NaN
# 502                                                NaN
# 503                                     2 mos\n3 mos\n
# 504                                                NaN
#
#                                              Education  \
# 0                                                  NaN
# 1                                                  NaN
# 2     \nLebanese University - Faculty of Engineerin...
# 3                                                  NaN
# 4     \nLebanese University - Faculty of Sciences -...
# ..                                                 ...
# 500   \nAntonine University - Baabda - Banking and ...
# 501                                                NaN
# 502   \nLebanese International University - Compute...
# 503                                                NaN
# 504   \nUniversité de Franche-Comté - Computer Engi...
#
#                                          Certification  \
# 0                                                  NaN
# 1     \nVerified International Academic Qualificati...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 500                                                NaN
# 501                                                NaN
# 502                                                NaN
# 503   \nFull-Stack Engineer Career Path - Codecadem...
# 504                                                NaN
#
#                                           Volunteering VolunteeringDuration  \
# 0                                                  NaN                  NaN
# 1                                  \nMilitante - AIDES        7 yrs 8 mos\n
# 2                                                  NaN                  NaN
# 3                                                  NaN                  NaN
# 4                                                  NaN                  NaN
# ..                                                 ...                  ...
# 500   \nChef de Patrouille - Scout du Liban \nTreas...       6 yrs\n3 yrs\n
# 501                                                NaN                  NaN
# 502                                                NaN                  NaN
# 503                                                NaN                  NaN
# 504                                                NaN                  NaN
#
#     Connections  Recommendations
# 0         500+               0.0
# 1         500+               0.0
# 2          232               0.0
# 3           41               NaN
# 4           15               NaN
# ..          ...              ...
# 500         57               NaN
# 501         10               0.0
# 502         51               NaN
# 503         21               NaN
# 504         38               NaN
#
# [388 rows x 16 columns]

# %%
print(df.isna().sum())
# Out:
# Name                      0
# Job                       0
# Location                  0
# Company                   2
# College                 128
# LinkedinLink              0
# Projects                317
# Languages               221
# Experience              167
# ExperienceDuration      167
# Education               246
# Certification           312
# Volunteering            342
# VolunteeringDuration    342
# Connections              22
# Recommendations         188
# dtype: int64

# %%
df.describe()
# Out:
#         Projects   Languages  Recommendations
# count  71.000000  167.000000        200.00000
# mean    3.464789    2.928144          0.02500
# std     3.065154    0.803373          0.18587
# min     1.000000    1.000000          0.00000
# 25%     1.000000    2.000000          0.00000
# 50%     2.000000    3.000000          0.00000
# 75%     4.500000    3.000000          0.00000
# max    16.000000    5.000000          2.00000

# %% [markdown]
# ### Recommendations don't seems to be popular amogst this age group in my set.

# %%
print('number of rows that have both college and education missing:', df[df['Education'].isnull() & df['College'].isnull()].shape[0])
# HOW IS THAT EVEN POSSIBLE MAAAAAAMMM

#indexNames = df2[ df2['location_type'] != 'county' ].index
#print(indexNames)
# Out:
# number of rows that have both college and education missing: 79

# %%
df.Education.dtypes
#df['C'] = df["Education"].apply(lambda L: L.rstrip("\n"))
df['C'] = df["Education"].astype(str).str.replace('\n', '')

# %%
df['D'] = df[""].astype(str).str.strip()
#new_df = df.apply(lambda x: np.square(x) if x.name == 'z' else x)
#split(':')[0]

# %%
df['D'] = df["D"].astype(str).str.split('-').str[0]

# %%
df['University Name'].unique().tolist()
# Out:
# ['nan',
#  'Lebanese University',
#  'Notre Dame University',
#  'Online Learning Consortium',
#  'University of Balamand',
#  'Lebanese International University',
#  'American University of Beirut',
#  'Haigazian University',
#  'Lebanese American University',
#  'Université Saint',
#  'Saint Joseph University of Beirut',
#  'Beirut Arab University',
#  'American University of Science and Technology',
#  'Holy Spirit University of Kaslik',
#  'Kingston University',
#  'AUL university',
#  'Université de Franche',
#  'Lebanese university faculty of agronomy',
#  'Antonine University']

# %%
len(df['College'].unique().tolist())

# %%
df['University Name'] = df['D']

# %%
df = df.drop(['D', 'C'], axis = 1)

# %%
df
# Out:
#                        Name  \
# 0    Dr. Hilal El Misilmani
# 1            Basma Frangieh
# 2          Hassan Nasrallah
# 3               Tony Kassab
# 4              Elie Yammine
# ..                      ...
# 500           Perla Ibrahim
# 501        SarkiS Fadlallah
# 502      Youssef Noureddine
# 503             Fadi Haddad
# 504          Elias Chalouhy
#
#                                                    Job  \
# 0    Assistant Professor | Graduate Studies Coordin...
# 1    Présidente de T.I.E.S (Together for Inclusive ...
# 2    Graduate Research Assistant - Computer Vision ...
# 3                     Molecular and cellular biologist
# 4               Statistician at Statistics Lebanon Ltd
# ..                                                 ...
# 500  Accountant at Logistica SAL - Obegi Consumer P...
# 501  Telecommunications Specialist at Advanced Inte...
# 502                  Computer & Communication Engineer
# 503                         Computer Engineer Graduate
# 504  Master's student in Computer Communication Eng...
#
#                                     Location  \
# 0                       Lebanon Contact info
# 1                       Lebanon Contact info
# 2                       Lebanon Contact info
# 3               Beirut, Lebanon Contact info
# 4    Qabb Elias, Beqaa, Lebanon Contact info
# ..                                       ...
# 500                     Lebanon Contact info
# 501                     Lebanon Contact info
# 502                     Lebanon Contact info
# 503     Tripoli, North, Lebanon Contact info
# 504                     Lebanon Contact info
#
#                                              Company  \
# 0                             Beirut Arab University
# 1        Université Libanaise - Faculté de Pédagogie
# 2    National Council for Scientific Research (CNRS)
# 3                                Lebanese university
# 4                             Statistics Lebanon Ltd
# ..                                               ...
# 500                  Obegi Consumer Products Holding
# 501                Advanced Integration Technologies
# 502                Lebanese International University
# 503                                  AI Venture Labs
# 504                      Université de Franche-Comté
#
#                                               College  \
# 0                       American University of Beirut
# 1                                                 NaN
# 2    Lebanese University - Faculty of Engineering III
# 3                                                 NaN
# 4           Lebanese University - Faculty of Sciences
# ..                                                ...
# 500                                               NaN
# 501                                               NaN
# 502                                               NaN
# 503                 Lebanese International University
# 504                                               NaN
#
#                                           LinkedinLink  Projects  Languages  \
# 0          https://lb.linkedin.com/in/hilalelmisilmani       NaN        3.0
# 1    https://lb.linkedin.com/in/basma-frangieh-0493...       2.0        3.0
# 2    https://lb.linkedin.com/in/hassan-nasrallah-38...       6.0        NaN
# 3     https://lb.linkedin.com/in/tony-kassab-75936a139       NaN        NaN
# 4    https://lb.linkedin.com/in/elie-yammine-a5b61918a       NaN        NaN
# ..                                                 ...       ...        ...
# 500  https://lb.linkedin.com/in/perla-ibrahim-6632a...       NaN        3.0
# 501  https://lb.linkedin.com/in/sarkis-fadlallah-18...       NaN        NaN
# 502  https://lb.linkedin.com/in/youssef-noureddine-...       NaN        NaN
# 503   https://lb.linkedin.com/in/fadi-haddad-4303a5164       NaN        NaN
# 504          https://lb.linkedin.com/in/elias-chalouhy       NaN        NaN
#
#                                             Experience  \
# 0                                                  NaN
# 1     \nConsultante en sciences de l'éducation - - ...
# 2     \nGraduate Research Assistant - Computer Visi...
# 3                                                  NaN
# 4     \nStatistician - Statistics Lebanon Ltd Full-...
# ..                                                 ...
# 500   \nAccountant - Obegi Consumer Products Holdin...
# 501                                                NaN
# 502                                                NaN
# 503   \nMachine Learning & AI Intern - AI Venture L...
# 504                                                NaN
#
#                                     ExperienceDuration  \
# 0                                                  NaN
# 1    5 yrs 8 mos\n2 yrs 5 mos\n11 mos\n1 yr\nLocati...
# 2                                7 mos\n6 mos\n3 mos\n
# 3                                                  NaN
# 4                                       2 mos\n9 mos\n
# ..                                                 ...
# 500  6 mos\n1 mo\n1 mo\nless than a year\nless than...
# 501                                                NaN
# 502                                                NaN
# 503                                     2 mos\n3 mos\n
# 504                                                NaN
#
#                                              Education  \
# 0                                                  NaN
# 1                                                  NaN
# 2     \nLebanese University - Faculty of Engineerin...
# 3                                                  NaN
# 4     \nLebanese University - Faculty of Sciences -...
# ..                                                 ...
# 500   \nAntonine University - Baabda - Banking and ...
# 501                                                NaN
# 502   \nLebanese International University - Compute...
# 503                                                NaN
# 504   \nUniversité de Franche-Comté - Computer Engi...
#
#                                          Certification  \
# 0                                                  NaN
# 1     \nVerified International Academic Qualificati...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 500                                                NaN
# 501                                                NaN
# 502                                                NaN
# 503   \nFull-Stack Engineer Career Path - Codecadem...
# 504                                                NaN
#
#                                           Volunteering VolunteeringDuration  \
# 0                                                  NaN                  NaN
# 1                                  \nMilitante - AIDES        7 yrs 8 mos\n
# 2                                                  NaN                  NaN
# 3                                                  NaN                  NaN
# 4                                                  NaN                  NaN
# ..                                                 ...                  ...
# 500   \nChef de Patrouille - Scout du Liban \nTreas...       6 yrs\n3 yrs\n
# 501                                                NaN                  NaN
# 502                                                NaN                  NaN
# 503                                                NaN                  NaN
# 504                                                NaN                  NaN
#
#     Connections  Recommendations                    University Name
# 0         500+               0.0                                nan
# 1         500+               0.0                                nan
# 2          232               0.0                Lebanese University
# 3           41               NaN                                nan
# 4           15               NaN                Lebanese University
# ..          ...              ...                                ...
# 500         57               NaN                Antonine University
# 501         10               0.0                                nan
# 502         51               NaN  Lebanese International University
# 503         21               NaN                                nan
# 504         38               NaN              Université de Franche
#
# [388 rows x 17 columns]

# %%
df['University Name'] = df['University Name'].astype(str).str.replace('Université Saint', 'Saint Joseph University')

# %%
df['University Name'] = df['University Name'].astype(str).str.replace('Saint Joseph University of Beirut', 'Saint Joseph University')

# %%
df['University Name'].unique().tolist()
# Out:
# ['nan',
#  'Lebanese University',
#  'Notre Dame University',
#  'Online Learning Consortium',
#  'University of Balamand',
#  'Lebanese International University',
#  'American University of Beirut',
#  'Haigazian University',
#  'Lebanese American University',
#  'Saint Joseph University',
#  'Beirut Arab University',
#  'American University of Science and Technology',
#  'Holy Spirit University of Kaslik',
#  'Kingston University',
#  'AUL university',
#  'Université de Franche',
#  'Lebanese university faculty of agronomy',
#  'Antonine University']

# %%
df.to_csv('combined.csv', index=False)

# %%
df = df.drop(['D'], axis = 1)
